# %% [markdown]
# 机器学习开源模块 scikit-learn 实现最小二乘线性回归方法
#
# sklearn.linear_model.LinearRegression(fit_intercept=True, normalize=False, copy_X=True, n_jobs=1)
# - fit_intercept: 默认为 True，计算截距项。 截距项（intercept）是指线性回归方程中的常数项，表示在所有特征都为零时，目标变量的预测值
# - normalize: 默认为 False，不针对数据进行标准化处理。
# - copy_X: 默认为 True，即使用数据的副本进行操作，防止影响原数据。
# - n_jobs: 计算时的作业数量。默认为 1，若为 -1 则使用全部 CPU 参与运算。

# %%
import numpy as np

x = np.array([56, 72, 69, 88, 102, 86, 76, 79, 94, 74])
y = np.array([92, 102, 86, 110, 130, 99, 96, 102, 105, 92])

# %%
from sklearn.linear_model import LinearRegression

# 定义线性回归模型
model = LinearRegression()
model.fit(x.reshape(x.shape[0], 1), y)  # 训练, reshape 操作把数据处理成 fit 能接受的形状

# 得到模型 截距,拟合参数
model.intercept_, model.coef_
# Out:
# (41.33509168550617, array([0.75458428]))

# %%
import matplotlib.pyplot as plt

plt.scatter(x, y)  # 绘制散点图
plt.plot(x, model.predict(x.reshape(x.shape[0], 1)), "r")  # 绘制模型拟合的直线

# %%
# 预测
model.predict([[150]])
# Out:
# array([154.52273298])
